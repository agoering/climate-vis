# %%
import numpy as npimport matplotlib.pyplot as pltfrom matplotlib import mlabimport csv## read data into arrays of floats by yeardef readData(textData, min, max):        infile = open(textData,"r") ## read the data file        content = infile.read()        infile.close()        lines = content.split('\n') ## split up lines        data = []        for each in lines:  ## split each line into separate strings                if len(each) < 1:                        continue          ## get rid of the empty list                                           ##at the end                row = each.split()                temp = {'year':float(row[0]), 'value':float(row[1])}                if temp['year'] >= min and temp['year'] <= max:                    data.append(temp)  ##for each data category year, value for the period starting in 1900        return data

# %%
precipData = readData('totalPrecipGlobalAvg.csv', 1900, 2010)tempData = readData('avgTempGlobalAvg.csv', 1900, 2010)co2Data = readData('yrTotCO2.csv', 1900, 2010)iceData = readData('iceExtSummerAvg.csv', 1900, 2010)precipRate = readData('rateOfChangeTotalPrecipGlobalAvg.csv', 1902, 2008)tempRate = readData('rateOfChangeAvgTempGlobalAvg.csv', 1902, 2008)co2Rate = readData('rateOfChangeTotalCO2emissions.csv', 1902, 2008)iceRate = readData('rateOfChangeIceExtSummerAvg.csv', 1902, 2008)

# %%
print precipRate
# Out:
# [{'value': -0.6860639765476207, 'year': 1902.5}, {'value': 1.0979798241089611, 'year': 1903.5}, {'value': -0.0015330229355640767, 'year': 1904.5}, {'value': -0.8281746852901051, 'year': 1905.5}, {'value': 3.9141170891524326, 'year': 1906.5}, {'value': 2.4031117434048612, 'year': 1907.5}, {'value': 0.10666839109969714, 'year': 1908.5}, {'value': 5.299446456286091, 'year': 1909.5}, {'value': 4.8321314019647845, 'year': 1910.5}, {'value': -9.66812898775645, 'year': 1911.5}, {'value': 5.432083979995559, 'year': 1912.5}, {'value': 7.353413519573792, 'year': 1913.5}, {'value': 5.817357302983192, 'year': 1914.5}, {'value': -3.2317675461274122, 'year': 1915.5}, {'value': 4.427543541989303, 'year': 1916.5}, {'value': -3.625100017243949, 'year': 1917.5}, {'value': -3.9398215209520004, 'year': 1918.5}, {'value': 2.89181065701041, 'year': 1919.5}, {'value': -0.33721158820519576, 'year': 1920.5}, {'value': 4.759935333678618, 'year': 1921.5}, {'value': 4.036995171580929, 'year': 1922.5}, {'value':
# ...

# %%
data = []rates = []yearVals = []for each in precipData:    yearVals.append(each['year'])    midInt = []for each in precipRate:    midInt.append(each['year'])    ## make an array of years, precipitation, temperature, CO2, ice extent values    for i in range(len(yearVals)):    temp = [yearVals[i], precipData[i]['value'], tempData[i]['value'], co2Data[i]['value'], iceData[i]['value']]    data.append(temp)    ## write all data values into a single csv filewith open('yr_Precip_Temp_CO2_Ice.csv', 'wb') as f:    wtr = csv.writer(f, delimiter= ' ')    wtr.writerows(data)## the file will contain years 1900 - 2010, precipitation in millimiters## temperature in degrees celcius, CO2 emission in millions of metric tons,## and Arctic sea ice extent in square kilometers## make an array of years, precipitation, temperature, CO2, ice extent values    for i in range(len(midInt)):    temp = [midInt[i], precipRate[i]['value'], tempRate[i]['value'], co2Rate[i]['value'], iceRate[i]['value']]    rates.append(temp)    ## write all rate values into a single csv filewith open('yr_ratePrecip_rateTemp_rateCO2_rateIce.csv', 'wb') as f:    wtr = csv.writer(f, delimiter= ' ')    wtr.writerows(rates)## the file will contain years 1902 - 2008, precipitation rate in millimiters per year## temperature rate in degrees celcius per year, CO2 emission rate in millions of metric ## tons per year, and Arctic sea ice extent rate in square kilometers per year

# %%
print len(yearVals), len(precipData), len(tempData), len(co2Data), len(iceData)print len(midInt), len(precipRate), len(tempRate), len(co2Rate), len(iceRate)
# Out:
# 111 111 111 111 111106 106 106 106 106

# %%
precip = []temperature = []co2 = []ice = []for each in data:    precip.append(each[1])    temperature.append(each[2])    co2.append(each[3])    ice.append(each[4])fig = plt.figure(figsize=(10, 10))plt.xlabel('year')plt.ylabel('Total global average annual precipitation in millimiters')plt.title('Total global average annual precipitation')plt.plot(yearVals, precip)plt.show()fig = plt.figure(figsize=(10, 10))plt.xlabel('year')plt.ylabel('Average global averaged annual temperature in degrees celcius')plt.title('Average global averaged annual temperature')plt.plot(yearVals, temperature)plt.show()fig = plt.figure(figsize=(10, 10))plt.xlabel('year')plt.ylabel('Total annual CO2 emissions in millions of metric tons')plt.title('total annual CO2 emissions')plt.plot(yearVals, co2)plt.show()fig = plt.figure(figsize=(10, 10))plt.xlabel('year')plt.ylabel('Summer averaged Arctic Sea ice extent in square kilometers')plt.title('Summer averaged Arctic Sea ice extent')plt.plot(yearVals, ice)plt.show()

# %%
precipRate = []temperatureRate = []co2Rate = []iceRate = []for each in rates:    precipRate.append(each[1])    temperatureRate.append(each[2])    co2Rate.append(each[3])    iceRate.append(each[4])fig = plt.figure(figsize=(10, 10))plt.xlabel('year')plt.ylabel('Total global average annual precipitation rate in millimiters per year')plt.title('Total global average annual precipitation rate')plt.plot(midInt, precipRate)plt.show()fig = plt.figure(figsize=(10, 10))plt.xlabel('year')plt.ylabel('Average global averaged annual temperature rate in degrees celcius per year')plt.title('Average global averaged annual temperature rate')plt.plot(midInt, temperatureRate)plt.show()fig = plt.figure(figsize=(10, 10))plt.xlabel('year')plt.ylabel('Total annual CO2 emissions rate in millions of metric tons per year')plt.title('total annual CO2 emissions rate')plt.plot(midInt, co2Rate)plt.show()fig = plt.figure(figsize=(10, 10))plt.xlabel('year')plt.ylabel('Summer averaged Arctic Sea ice extent rate rate in square kilometers per year')plt.title('Summer averaged Arctic Sea ice extent rate')plt.plot(midInt, iceRate)plt.show()
