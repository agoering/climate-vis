# %%
import numpy as npimport matplotlib.pyplot as plt## read data into arrays of floats by yeardef readData(textData):        infile = open(textData,"r") ## read the data file        content = infile.read()        infile.close()        lines = content.split('\n') ## split up lines        data = []        for each in lines:  ## split each line into separate strings                if len(each) < 1:                        continue          ## get rid of the empty list                                           ##at the end                temp = each.split()                data.append(temp)    ## data contains lists of data                                          ##for each year## latitude, longitude, january - december rainfall in millimeters         floatData = []        for each in data:                tempLine = []                for element in each:                        temp = float(element)                        tempLine.append(temp)                floatData.append(tempLine)        return floatDatadef precipDuringYear(year):  ## read data during the year of interest        temp = readData("PrecipData/precip."+str(year))        return temp## list of precipitation data for each yeardef temperatureDuringYear(year):  ## read data during the year of interest        temp = readData("TempData/air_temp."+str(year))        return temp## list of temperature data for each yeardef dataPlot(data, title):    lat_vals = []    lon_vals = []    data_vals = []    for i in range(0, len(data)):         temp1 = data[i][0] ## lattitude values        temp2 = data[i][1] ## longitude values        temp3 = 0.        for j in range(2, len(data[i])):  ## annual average over 12 montsh            temp3 += data[i][j]            temp4 = temp3 / (len(data[i])-2)#        temp4 = temperature[i][12]  ## monthly values 3 - 14 for Jan - Dec        lat_vals.append(temp1)        lon_vals.append(temp2)        data_vals.append(temp4)    fig = plt.figure(figsize=(12, 6))    plt.xlabel('lattitude')    plt.ylabel('longitude')    plt.title(title)    plt.scatter(lat_vals, lon_vals, c=data_vals, edgecolors='none')    plt.colorbar()    plt.show()

# %%
yr = 1905temperature = temperatureDuringYear(yr)precip = precipDuringYear(yr)dataPlot(temperature,'Temperature in degrees Celcius in year '+str(yr))dataPlot(precip, 'Precipitation in millimiters in year '+str(yr))

# %%
yr = 1909temperature = temperatureDuringYear(yr)precip = precipDuringYear(yr)dataPlot(temperature,'Temperature in degrees Celcius in year '+str(yr))dataPlot(precip, 'Precipitation in millimiters in year '+str(yr))

# %%
yr = 2005temperature = temperatureDuringYear(yr)precip = precipDuringYear(yr)dataPlot(temperature,'Temperature in degrees Celcius in year '+str(yr))dataPlot(precip, 'Precipitation in millimiters in year '+str(yr))

# %%
yr = 2009temperature = temperatureDuringYear(yr)precip = precipDuringYear(yr)dataPlot(temperature,'Temperature in degrees Celcius in year '+str(yr))dataPlot(precip, 'Precipitation in millimiters in year '+str(yr))

# %%
#fig = plt.figure()#ax = Axes3D(fig)#X, Y = np.meshgrid(lat_vals[0:len(lat_vals):500], lon_vals[0:len(lon_vals):500])#Z = precip_vals[0:len(precip_vals):500]  #surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.jet,#        linewidth=0, antialiased=False)#plt.xlabel('Latitude')  #plt.ylabel('Longitude')#ax.w_zaxis.set_major_locator(LinearLocator(10))#ax.w_zaxis.set_major_formatter(FormatStrFormatter('%.03f'))    #fig.colorbar(surf, shrink=0.5, aspect=5) #lat = lat_vals[0:len(lat_vals):10]#lon = lon_vals[0:len(lon_vals):10]#intensity= precip_vals[0:len(precip_vals):10] #plt.subplot(111)
